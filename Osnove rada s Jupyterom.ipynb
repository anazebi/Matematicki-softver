# %% [markdown]
# # Osnovno o Jupyteru i primjeri korištenja
#
# ## Metapodaci o kolegiju

# %% [markdown]
# ### Materijali
#
# Materijali se objavljuju prvenstveno na Merlinu. Svi **studenti koji planiraju položiti ovaj kolegij**, moraju imati upisan e-kolegij "Matematički softver" na Merlinu. Bez toga je nemoguće npr. predati prvi esej, što je nužni uvjet za prolaz kolegija.

# %% [markdown]
# ### Sadržaj kolegija
#
# * IPython / Jupyter
# * Scipy stack: Numpy, Sympy, Pandas, Matplotlib
# * Markdown
# * LaTeX: KOMAScript, amsmath+mathtools, babel+csquotes
#
# ### Cilj kolegija
#
# * Razviti sposobnost korištenja Pythona kao moćnog alata za znanstvenike
# * Osposobiti vas za produkciju visokokvalitetnih publikacija (interaktivnih bilježnica, matematičkih članaka i prezentacija)
#
# ### Polaganje
#
# Ocjena se formira iz dva kolokvija, tjednih zadaća i eseja. Kolokviji su tipa _open-book_ i nose 2⋅20=40 bodova. Domaće zadaće su tjedni zadačići objavljeni na Merlinu (20 bodova) i dvije velike zadaće u obliku eseja/projekta sa zadanim elementima.
#
# Predaja oba eseja nužan je uvjet za polaganje kolegija. Esej je uspješno predan samo ako ima _sve_ tražene elemente. Eseji nose 2⋅20=40 bodova, koji se dodjeljuju za _dodatne_ elemente. Bodove za eseje dodjeljujete si međusobno prema jasno definiranim rubrikama (_peer review_).
#
# Popravni kolokvij sastoji se u ponovnom pisanju jednog kolokvija po izboru studenta. U slučaju opravdane spriječenosti prisustvovanja kolokviju, javite se što prije da dogovorimo alternativne metode ocjenjivanja.
#
# ### Literatura / materijali _online_
#
# * [Lectures on scientific computing with Python](https://github.com/jrjohansson/scientific-python-lectures) - kolegij po uzoru na koji je ovaj nastao (davno)
#
# * [Astro 599 Course](http://nbviewer.jupyter.org/github/jakevdp/2013_fall_ASTR599/tree/master/notebooks/) - još jedan sličan kolegij, nažalost u Pythonu 2 ali s puno korisnih informacija
#
# * [Reproducible data analysis in Jupyter](http://jakevdp.github.io/blog/2017/03/03/reproducible-data-analysis-in-jupyter/) - serija videâ koji detaljno objašnjavaju _workflow_ potreban za "idealnu" prvu zadaću
#
# * [xkcd 1313: Regex Golf](http://nbviewer.jupyter.org/url/norvig.com/ipython/xkcd1313.ipynb) - duhovit ali i poučan primjer netrivijalnog rezultata dobivenog pomoću Jupytera
#
# * [A gallery of interesting Jupyter Notebooks](https://github.com/jupyter/jupyter/wiki) - ogromni repozitorij raznovrsnih bilježnica, dobro za upoznavanje s mogućnostima

# %% [markdown]
# ## Primjeri
#
# ### Osnove rada s Jupyterom
#
# Tekst se nalazi u ćelijama, kojih ima tri vrste:
# * ulazne ćelije, gdje pišemo kod u Pythonu, označene s `In[`*broj*`]`
# * izlazne ćelije, gdje Python javlja rezultate, označene s `Out[`*broj*`]`
# * tekstne ćelije, gdje pišemo tekst u Markdownu
#
# *broj*evi gore se odnose na _vremenski_ tijek evaluacije pojedinih ćelija, koji se ne mora podudarati s prostornim. Ipak, za uredne dokumente, dobro je da se bilježnica može evaluirati "odozgo prema dolje" (Menu `Kernel`... `Restart & Run All`). U bilo kojem trenutku možemo s `_`*broj* referirati na rezultat pojedine naredbe (skraćeno samo `_` za zadnju izvršenu naredbu), iako je mnogo bolje rezultatima dati lijepa imena ako znamo da ćemo ih još koristiti.
#
# Trenutno odabranu ćeliju možemo pretvoriti u Python pomoću `Esc` `Y` ili u Markdown pomoću `Esc` `M`. Općenito, `Esc` nas prebacuje u način rada s ćelijama (plavi obrub) gdje pored promjene tipa određene ćelije možemo zadavati razne druge naredbe (`Help`... `Keyboard shortcuts` za popis svih, ovdje su najčešće korištene):
#
# * `C`, `X`, `V`: kopiranje, rezanje i lijepljenje ćelija
# * `J`, `K` ili strelice dolje/gore: kretanje između ćelija (+`Shift`: odabir više ćelija)
# * `A`, `B`: dodavanje nove ćelije iznad/ispod prethodne
# * `DD`: brisanje trenutno odabrane ćelije (dvostruki pritisak na `D`)
#
# Klik u ulaznu ćeliju (ili `Enter` kada je odabrana) pokreće način rada s kodom u ćeliji (zeleni obrub) gdje možemo pisati kod. Izvršavamo ga sa `Shift`+`Enter`. Također, dvostruki klik u tekstnu ćeliju (ili `Enter`) otvara nam _source_ (Markdown) te ćelije, gdje možemo vidjeti kako su pojedini efekti postignuti. `Shift`+`Enter` renderira tekstnu ćeliju kao običan (formatirani) tekst. Trostruki klik u izlaznu ćeliju odabire čitav izlaz u ćeliji kako bismo ga mogli prenijeti drugamo.

# %% [markdown]
# ### Slaganje bilježnica
#
# Možemo uključivati slike, zvukove, videe, matematičke zapise, objekte u formatu JSON,... Za detalje pogledati [dokumentaciju](http://ipython.readthedocs.io/en/stable/api/generated/IPython.display.html).

# %%
from IPython.display import Image, YouTubeVideo
Image('http://python.org/images/python-logo.gif')

# %%
YouTubeVideo('T4WXs6niloU')  # https://www.youtube.com/watch?v=T4WXs6niloU

# %% [markdown]
# Možemo i izvršavati sistemske naredbe (počinju uskličnikom `!`), ali time naša bilježnica postaje izvršiva samo na određenom operacijskom sustavu. Zato je dobro to izbjegavati.

# %%
# !dir
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 4E78-FCD4
#
#  Directory of C:\Users\Mia\Documents\Nastava\MS\2022
#
# 02.03.2022.  20:20    <DIR>          .
# 02.03.2022.  20:20    <DIR>          ..
# 02.03.2022.  20:14    <DIR>          .ipynb_checkpoints
# 02.03.2022.  20:20           198.105 Osnove rada s Jupyterom.ipynb
#                1 File(s)        198.105 bytes
#                3 Dir(s)  701.783.998.464 bytes free

# %% [markdown]
# ### Magične naredbe
#
# "Magične" naredbe počinju znakom `%`. Linijske (počinju jednim znakom `%`) primaju se odnose na tekst u jednom redu, ćelijske (počinju s `%%`) se odnose na tekst u čitavoj ćeliji.

# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %% [markdown]
# Slijede primjeri korištenja nekih magičnih naredbi: `%who` nam kaže koja smo sve imena definirali (ili uvezli), `%matplotlib` postavlja način na koji će se renderirati crteži (jednom kad ih budemo crtali), a `%xmode` postavlja način na koji se prijavljuju greške.

# %%
# %who
# Out:
# Image	 YouTubeVideo

# %%
# %matplotlib inline

# %%
# %xmode minimal
1/0
# Out:
# Exception reporting mode: Minimal
# ZeroDivisionError: division by zero

# %% [markdown]
# Što se ćelijskih magičnih naredbi tiče, često korištena je `%%time` za mjerenje vremena potrebnog za izvršavanje određenog koda. Pomoću `%%file` možemo proizvesti tekstne datoteke u radnom direktoriju. Također možemo zadavati ulaz u skoro bilo kojem jeziku čiji interpreter imamo (ovdje su za primjer navedeni HTML i JavaScript).

# %%
# %%time
zbroj = 0
for broj in range(10**7):
    zbroj += broj
print(zbroj)
# Out:
# 49999995000000
# Wall time: 1.71 s

# %%
# %%file generirana.txt
# Ovo je automatski generirana datoteka od strane Jupytera.
# Izvršavanjem ove ćelije zapisat će se u trenutni direktorij.
# Out:
# Writing generirana.txt

# %%
# %%HTML
# <h5>Neki naslov</h5>
# <p>Jedan jednostavni <em>primjer</em>.</p>
# <p>Sastoji se od dva odlomka teksta.</p>
# Out:
# <h5>Neki naslov</h5>
# <p>Jedan jednostavni <em>primjer</em>.</p>
# <p>Sastoji se od dva odlomka teksta.</p>

# %%
# %%js
# alert('hello')

# %%
# %less generirana.txt

# %% [markdown]
# ### Traženje pomoći
#
# Dodavanjem `?` (ili `??` za više detalja) na praktički bilo koje ime možemo zatražiti pomoć u vezi objekta imenovanog tim imenom. Pomoć se prikazuje u zasebnom prozoru. `help` je standardni Pythonov help.

# %%
YouTubeVideo?

# %%
help(chr)
# Out:
# Help on built-in function chr in module builtins:
#
# chr(i, /)
#     Return a Unicode string of one character with ordinal i; 0 <= i <= 0x10ffff.

# %% [markdown]
# S `type` možemo saznati kojeg je tipa pojedini objekt, a s `dir` koje atribute (i metode) pojedini objekt ili tip podržava.

# %%
type( (3, 1, 3, 8, 9) )
# Out:
# tuple

# %%
dir(tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
help(tuple.count)
# Out:
# Help on method_descriptor:
#
# count(self, value, /)
#     Return number of occurrences of value.

# %%
(3, 1, 3, 8, 9).count(3)
# Out:
# 2

# %% [markdown]
# ### Kompleksniji primjer
#
# Učitamo potrebne biblioteke: [`skimage`](https://scikit-image.org/docs/dev/api/skimage.html) za rad sa slikama i [`matplotlib`](https://matplotlib.org/) za vizualizaciju. Dohvatimo sliku novčićâ iz biblioteke primjera i prikažemo je kao crno-bijelu.

# %%
from skimage import data
import matplotlib.pyplot as plt
coins = data.coins()
plt.imshow(coins, cmap='gray')

# %% [markdown]
# `.shape` je uređeni par koji predstavlja dimenzije slike: `(`*redci*`, `*stupci*`)`. Operatorom `[]` možemo iz slike "vaditi" pojedine piksele ili isječke: ovdje smo izrezali novčić koji je prikazan od 10. do 80. retka i od 300. do 370. stupca.

# %%
coins.shape
# Out:
# (303, 384)

# %%
coins_zoom = coins[10:80, 300:370]

# %% [markdown]
# Veliki paketi često sadrže podpakete koji se učitavaju isto kao i objekti/klase/funkcije. `skimage.restoration` je zbirka filtera koje možemo primjenjivati na slike. Jedan od njih je [`denoise_tv_chambolle`](https://scikit-image.org/docs/dev/api/skimage.restoration.html#skimage.restoration.denoise_tv_chambolle).

# %%
from skimage import restoration
tv_coins = restoration.denoise_tv_chambolle(coins_zoom, weight=.05)

# %% [markdown]
# Prikazujemo isječke jedan pored drugog: lijevo prije primjene filtera, desno poslije.

# %%
slika, (lijevo, desno) = plt.subplots(ncols=2)
lijevo.imshow(coins_zoom)
desno.imshow(tv_coins)

# %% [markdown]
# ### Interaktivnost
#
# Jupyter ima brojne [mogućnosti za interaktivni rad](https://ipywidgets.readthedocs.io/en/latest/examples/Using%20Interact.html). Pokažimo samo neke.

# %%
from ipywidgets import interact
interact(lambda x=8, y=1, brže=True: x + y**2 if brže else x + 2*y)
# Out:
# interactive(children=(IntSlider(value=8, description='x', max=24, min=-8), IntSlider(value=1, description='y',…
# <function __main__.<lambda>(x=8, y=1, brže=True)>

# %%
import networkx as nx
interact(lambda n=(2, 30), m=(1, 10), p=(0, 1, 1e-3), generator={
                   'lobster': lambda n, m, p: nx.random_lobster(n, p, p / m),
                 'power law': lambda n, m, p: nx.powerlaw_cluster_graph(n, m, p),
     'Newman-Watts-Strogatz': lambda n, m, p: nx.newman_watts_strogatz_graph(n, m, p),
               'Erdős-Rényi': lambda n, m, p: nx.erdos_renyi_graph(n, p),
}: nx.draw(generator(n, m, p)));
# Out:
# interactive(children=(IntSlider(value=16, description='n', max=30, min=2), IntSlider(value=5, description='m',…
